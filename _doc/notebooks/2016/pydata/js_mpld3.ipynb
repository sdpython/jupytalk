# %% [markdown]
# # mpld3
#
# [mpld3](http://mpld3.github.io/) is taking *matplotlib* graphs and converts them into javascript. the support was stopped in Summer 2017. This notebook should be failing at some point is not checked anymore on regular basis.

# %% [markdown]
# [documentation](http://mpld3.github.io/) [source](https://github.com/mpld3/mpld3) [installation](http://mpld3.github.io/install.html) [tutorial](http://mpld3.github.io/_downloads/mpld3_demo.html) [gallery](http://mpld3.github.io/examples/index.html)

# %%
from jyquickhelper import add_notebook_menu
add_notebook_menu()
# Out:
# <div id="my_id_menu_nb">run previous cell, wait for 2 seconds</div>
# <script>
# function repeat_indent_string(n){
#     var a = "" ;
#     for ( ; n > 0 ; --n) {
#         a += "    ";
#     }
#     return a;
# }
# var update_menu_string = function(begin, lfirst, llast, sformat, send, keep_item) {
#     var anchors = document.getElementsByClassName("section");
#     if (anchors.length == 0) {
#         anchors = document.getElementsByClassName("text_cell_render rendered_html");
#     }
#     var i,t;
#     var text_menu = begin;
#     var text_memo = "<pre>\nlength:" + anchors.length + "\n";
#     var ind = "";
#     var memo_level = 1;
#     var href;
#     var tags = [];
#     var main_item = 0;
#     for (i = 0; i <= llast; i++) {
#         tags.push("h" + i);
#     }
#
#     for (i = 0; i < anchors.length; i++) {
#         text_memo += "**" + anchors[i].id + "--\n";
#
#         var child = null;
#         for(t = 0; t < tags.length; t++) {
#             var r = anchors[i].getElementsByTagName(tags[t]);
#             if (r.length > 0) {
# child = r[0];
# break;
#             }
#         }
#         if (child == null){
#             text_memo += "null\n";
#             continue;
#         }
#         if (anchors[i].hasAttribute("id")) {
#             // when converted in RST
#             href = anchors[i].id;
#             text_memo += "#1-" + href;
#             // passer à child suivant (le chercher)
#         }
#         else if (child.hasAttribute("id")) {
#             // in a notebook
#             href = child.id;
#             text_memo += "#2-" + href;
#         }
#         else {
#             text_memo += "#3-" + "*" + "\n";
#             continue;
#         }
#         var title = child.textContent;
#         var level = parseInt(child.tagName.substring(1,2));
#
#         text_memo += "--" + level + "?" + lfirst + "--" + title + "\n";
#
#         if ((level < lfirst) || (level > llast)) {
#             continue ;
#         }
#         if (title.endsWith('¶')) {
#             title = title.substring(0,title.length-1).replace("<", "&lt;").replace(">", "&gt;").replace("&", "&amp;")
#         }
#
#         if (title.length == 0) {
#             continue;
#         }
#
#         while (level < memo_level) {
#             text_menu += "</ul>\n";
#             memo_level -= 1;
#         }
#         if (level == lfirst) {
#             main_item += 1;
#         }
#         if (keep_item != -1 && main_item != keep_item + 1) {
#             // alert(main_item + " - " + level + " - " + keep_item);
#             continue;
#         }
#         while (level > memo_level) {
#             text_menu += "<ul>\n";
#             memo_level += 1;
#         }
#         text_menu += repeat_indent_string(level-2) + sformat.replace("__HREF__", href).replace("__TITLE__", title);
#     }
#     while (1 < memo_level) {
#         text_menu += "</ul>\n";
#         memo_level -= 1;
#     }
#     text_menu += send;
#     //text_menu += "\n" + text_memo;
#     return text_menu;
# };
# var update_menu = function() {
#     var sbegin = "";
#     var sformat = '<li><a href="#__HREF__">__TITLE__</a></li>';
#     var send = "";
#     var keep_item = -1;
#     var text_menu = update_menu_string(sbegin, 2, 4, sformat, send, keep_item);
#     var menu = document.getElementById("my_id_menu_nb");
#     menu.innerHTML=text_menu;
# };
# window.setTimeout(update_menu,2000);
#             </script>

# %% [markdown]
# ## example

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import mpld3
import numpy

# %%
fig, ax = plt.subplots()
N = 100
scatter = ax.scatter(numpy.random.normal(size=N), numpy.random.normal(size=N), c=numpy.random.random(size=N),
                    s=1000 * numpy.random.random(size=N), alpha=0.3, cmap=plt.cm.jet)
ax.set_title("Scatter Plot", size=20)
labels = ['point {0}'.format(i + 1) for i in range(N)]
mpld3.display(fig)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el749219755134656888681591388"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el749219755134656888681591388", {"width": 480.0, "axes": [{"xlim": [-3.0, 3.0], "markers": [], "bbox": [0.125, 0.125, 0.775, 0.775], "yscale": "linear", "zoomable": true, "xscale": "linear", "sharey": [], "ylim": [-3.0, 3.0], "id": "el74921975519983320", "lines": [], "axesbg": "#FFFFFF", "axesbgalpha": null, "texts": [{"fontsize": 20.0, "coordinates": "axes", "position": [0.5, 1.0224014336917562], "id": "el74921975520177176", "zorder": 3, "text": "Scatter Plot", "rotation": -0.0, "h_anchor": "middle", "color": "#000000", "v_baseline": "auto", "alpha": 1}], "images": [], "xdomain": [-3.0, 3.0], "ydomain": [-3.0, 3.0], "paths": [], "axes": [{"fontsize": 10.0, "tickformat": null, "nticks": 7, "tickvalues": null, "position": "bottom", "grid": {"gridOn": false}, "scale": "linear"}, {"fontsize": 10.0, "tickformat": null, "nticks": 7, "tickvalues": null, "position": "left", "grid": {"gridOn": false}, "scale": "linear"}], "sharex": [], "collections": [{"offsets": "data01", "id": "el74921975520317624", "offsetcoordinates": "data", "alphas": [0.3], "edgecolors": ["#000000"], "zorder": 1, "pathtransforms": [[27.648327813314456, 0.0, 0.0, 27.648327813314456, 0.0, 0.0], [16.742443678512863, 0.0, 0.0, 16.742443678512863, 0.0, 0.0], [34.52145625548877, 0.0, 0.0, 34.52145625548877, 0.0, 0.0], [28.482835855289107, 0.0, 0.0, 28.482835855289107, 0.0, 0.0], [3.7932085884312974, 0.0, 0.0, 3.7932085884312974, 0.0, 0.0], [20.854372999392123, 0.0, 0.0, 20.854372999392123, 0.0, 0.0], [29.955460603074584, 0.0, 0.0, 29.955460603074584, 0.0, 0.0], [13.572909270578187, 0.0, 
# %% [markdown]
# ``mpld3.display(fig)`` displays the graph. You can use ``mpld3.enable_notebook()`` to avoid that but *matplotlib* will not be available.

# %% [markdown]
# ## Same graph with a plugin

# %%
fig, ax = plt.subplots()
N = 100
scatter = ax.scatter(numpy.random.normal(size=N), numpy.random.normal(size=N), c=numpy.random.random(size=N),
                    s=1000 * numpy.random.random(size=N), alpha=0.3, cmap=plt.cm.jet)
ax.set_title("Scatter Plot", size=20)
labels = ['point {0}'.format(i + 1) for i in range(N)]

# addition
tooltip = mpld3.plugins.PointLabelTooltip(scatter, labels=labels)
mpld3.plugins.connect(fig, tooltip)

mpld3.display(fig)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el749219755195975687597978175"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el749219755195975687597978175", {"width": 480.0, "axes": [{"xlim": [-3.0, 4.0], "markers": [], "bbox": [0.125, 0.125, 0.775, 0.775], "yscale": "linear", "zoomable": true, "xscale": "linear", "sharey": [], "ylim": [-3.0, 4.0], "id": "el74921975519596896", "lines": [], "axesbg": "#FFFFFF", "axesbgalpha": null, "texts": [{"fontsize": 20.0, "coordinates": "axes", "position": [0.5, 1.0224014336917562], "id": "el74921975519585224", "zorder": 3, "text": "Scatter Plot", "rotation": -0.0, "h_anchor": "middle", "color": "#000000", "v_baseline": "auto", "alpha": 1}], "images": [], "xdomain": [-3.0, 4.0], "ydomain": [-3.0, 4.0], "paths": [], "axes": [{"fontsize": 10.0, "tickformat": null, "nticks": 8, "tickvalues": null, "position": "bottom", "grid": {"gridOn": false}, "scale": "linear"}, {"fontsize": 10.0, "tickformat": null, "nticks": 8, "tickvalues": null, "position": "left", "grid": {"gridOn": false}, "scale": "linear"}], "sharex": [], "collections": [{"offsets": "data01", "id": "el74921975519436752", "offsetcoordinates": "data", "alphas": [0.3], "edgecolors": ["#000000"], "zorder": 1, "pathtransforms": [[24.31920477330702, 0.0, 0.0, 24.31920477330702, 0.0, 0.0], [24.124515738225593, 0.0, 0.0, 24.124515738225593, 0.0, 0.0], [30.391545356742686, 0.0, 0.0, 30.391545356742686, 0.0, 0.0], [28.066039647285155, 0.0, 0.0, 28.066039647285155, 0.0, 0.0], [30.80850490829379, 0.0, 0.0, 30.80850490829379, 0.0, 0.0], [32.52245082469589, 0.0, 0.0, 32.52245082469589, 0.0, 0.0], [5.268227426816058, 0.0, 0.0, 5.268227426816058, 0.0, 0.0], [32.78581895449067, 0.0, 0.0, 32.78581895449067, 0.0, 0.0], [32.579052298254005, 0.0, 0.0, 32.579052298254005, 0.0, 0.0], [14.695784875447925, 0.0, 0.0, 14.695784875447925, 0.0, 0.0], [31.378844005001763, 0.0, 0.0, 31.378844005001763, 0.0, 0.0], [15.576845927001042, 0.0, 0.0, 15.576845927001042, 0.0, 0.0], [19.353910551034932, 0.0, 0.0, 19.353910551034932, 0.0, 0.0], [7.981810774468968, 0.0, 0.0, 7.981810774468968, 0.0, 0.0], [21.34
ig, ax = plt.subplots()
ax.grid(True, alpha=0.3)

N = 50
df = pd.DataFrame(index=range(N))
df['x'] = np.random.randn(N)
df['y'] = np.random.randn(N)
df['z'] = np.random.randn(N)

labels = []
for i in range(N):
    label = df.iloc[[i], :].T
    label.columns = ['Row {0}'.format(i)]
    # .to_html() is unicode; so make leading 'u' go away with str()
    labels.append(str(label.to_html()))

points = ax.plot(df.x, df.y, 'o', color='b',
                 mec='k', ms=15, mew=1, alpha=.6)

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('HTML tooltips', size=20)

tooltip = plugins.PointHTMLTooltip(points[0], labels,
                                   voffset=10, hoffset=10, css=css)
plugins.connect(fig, tooltip)

mpld3.display(fig)
# Out:
# <style>
#
# table
# {
#   border-collapse: collapse;
# }
# th
# {
#   color: #ffffff;
#   background-color: #000000;
# }
# td
# {
#   background-color: #cccccc;
# }
# table, th, td
# {
#   font-family:Arial, Helvetica, sans-serif;
#   border: 1px solid black;
#   text-align: right;
# }
#
# </style>
#
# <div id="fig_el749219755398441523757011934"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#     mpld3.register_plugin("htmltooltip", HtmlTooltipPlugin);
#     HtmlTooltipPlugin.prototype = Object.create(mpld3.Plugin.prototype);
#     HtmlTooltipPlugin.prototype.constructor = HtmlTooltipPlugin;
#     HtmlTooltipPlugin.prototype.requiredProps = ["id"];
#     HtmlTooltipPlugin.prototype.defaultProps = {labels:null, hoffset:0, voffset:10};
#     function HtmlTooltipPlugin(fig, props){
#         mpld3.Plugin.call(this, fig, props);
#     };
#
#     HtmlTooltipPlugin.prototype.draw = function(){
#        var obj = mpld3.get_element(this.props.id);
#        var labels = this.props.labels;
#        var tooltip = d3.select("body").append("div")
#                     .attr("class", "mpld3-tooltip")
#                     .style("position", "absolute")
#                     .style("z-index", "10")
#                     .style("visibility", "hidden");
#
#        obj.elements()
#            .on("mouseover", function(d, i){
#                               tooltip.html(labels[i])
#                                      .style("visibility", "visible");})
#            .on("mousemove", function(d, i){
#                     tooltip
#                       .style("top", d3.event.pageY + this.props.voffset + "px")
#                       .style("left",d3.event.pageX + this.props.hoffset + "px");
#                  }.bind(this))
#            .on("mouseout",  function(d, i){
#                            tooltip.style("visibility", "hidden");});
#     };
#
#        mpld3.draw_figure("fig_el749219755398441523757011934", {"width": 480.0, "axes": [{"xlim": [-2.5, 2.0], "markers": [{"markerpath": [[[0.0, 7.5], [1.9890232500000002, 7.5], [3.896849030886401, 6.709752686911813], [5.303300858899107, 5.303300858899107], [6.709752686911813, 3.896849030886401], [7.5, 1.9890232500000002], [7.5, 0.0], [7.5, -1.9890232500000002], [6.709752686911813, -3.896849030886401], [5.303300858899107, -5.303300858899107], [3.896849030886401, -6.709752686911813], [1.9890232500000002, -7.5], [0.0, -7.5], [-1.9890232500000002, -7.5], [-3.896849030886401, -6.709752686911813], [-5.303300858899107, -5.303300858899107], [-6.709752686911813, -3.896849030886401], [-7.5, -1.9890232500000002], [-7.5, 0.0], [-7.5, 1.9890232500000002], [-6.709752686911813, 3.896849030886401], [-5.303300858899107, 5.303300858899107], [-3.896849030886401, 6.709752686911813], [-1.9890232500000002, 7.5], [0.0, 7.5]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]], "facecolor": "#0000FF", "coordinates": "data", "alpha": 0.6, "edgewidth": 1, "edgecolor": "#000000", "zorder": 2, "xindex": 0, "id": "el74921975549022160pts", "yindex": 1, "data": "data01"}], "bbox": [0.125, 0.125, 0.775, 0.775], "yscale": "linear", "zoomable": true, "xscale": "linear", "sharey": [], "ylim": [-3.0, 3.0], "id": "el74921975548730336", "lines": [], "axesbg": "#FFFFFF", "axesbgalpha": null, "texts": [{"fontsize": 10.0, "coordinates": "axes", "position": [0.5, -0.08064516129032258], "id": "el74921975548759848", "zorder": 3, "text": "x", "rotation": -0.0, "h_anchor": "middle", "color": "#000000", "v_baseline": "hanging", "alpha": 1}, {"fontsize": 10.0, "coordinates": "axes", "position": [-0.07123655913978494, 0.5], "id": "el74921975548802608", "zorder": 3, "text": "y", "rotation": -90.0, "h_anchor": "middle", "color": "#000000", "v_baseline": "auto", "alpha": 1}, {"fontsize": 20.0, "coordinates": "axes", "position": [0.5, 1.0224014336917562], "id": "el74921975548862816", "zorder": 3, "text": "HTML tooltips", "rotation": -0.0, "h_anchor": "middle", "color": "#000000", "v_baseline": "auto", "alpha": 1}], "images": [], "xdomain": [-2.5, 2.0], "ydomain": [-3.0, 3.0], "paths": [], "axes": [{"fontsize": 10.0, "tickformat": null, "nticks": 10, "tickvalues": null, "position": "bottom", "grid": {"dasharray": "2,2", "color": "#000000", "alpha": 0.3, "gridOn": true}, "scale": "linear"}, {"fontsize": 10.0, "tickformat": null, "nticks": 7, "tickvalues": null, "position": "left", "grid": {"dasharray": "2,2", "color": "#000000", "alpha": 0.3, "gridOn": true}, "scale": "linear"}], "sharex": [], "collections": []}], "plugins": [{"type": "reset"}, {"enabled": false, "type": "zoom", "button": true}, {"enabled": false, "type": "boxzoom", "button": true}, {"id": "el74921975549022160pts", "hoffset": 10, "type": "htmltooltip", "voffset": 10, "labels": ["<table border=\"1\" class=\"dataframe\">\n  <thead>\n    <tr style=\"text-align: right;\">\n      <th></th>\n      <th>Row 0</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>x</th>\n      <td>0.777867</td>\n    </tr>\n    <tr>\n      <th>y</th>\n      <td>-1.211744</td>\n    </tr>\n    <tr>\n      <th>z</th>\n      <td>-0.128880</td>\n    </tr>\n  </tbody>\n</table>", "<table border=\"1\" class=\"dataframe\">\n  <thead>\n    <tr style=\"text-align: right;\">\n      <th></th>\n      <th>Row 1</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>x</th>\n      <td>1.592416</td>\n    </tr>\n    <tr>\n      <th>y</th>\n      <td>-0.489383</td>\n    </tr>\n    <tr>\n      <th>z</th>\n      <td>0.285444</td>\n    </tr>\n  </tbody>\n</table>", "<table border=\"1\" class=\"dataframe\">\n  <thead>\n    <tr style=\"text-align: right;\">\n      <th></th>\n      <th>Row 2</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>x</th>\n      <td>0.134520</td>\n    </tr>\n    <tr>\n      <th>y</th>\n      <td>0.720882</td>\n    </tr>\n    <tr>\n      <th>z</th>\n      <td>0.096167</td>\n    </tr>\n  </tbody>\n</table>", "<table bo ...

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

import mpld3
from mpld3 import plugins, utils


data = load_iris()
X = data.data
y = data.target

# dither the data for clearer plotting
X += 0.1 * np.random.random(X.shape)

fig, ax = plt.subplots(4, 4, sharex="col", sharey="row", figsize=(8, 8))
fig.subplots_adjust(left=0.05, right=0.95, bottom=0.05, top=0.95,
                    hspace=0.1, wspace=0.1)

for i in range(4):
    for j in range(4):
        points = ax[3 - i, j].scatter(X[:, j], X[:, i],
                                      c=y, s=40, alpha=0.6)

# remove tick labels
for axi in ax.flat:
    for axis in [axi.xaxis, axi.yaxis]:
        axis.set_major_formatter(plt.NullFormatter())

# Here we connect the linked brush plugin
plugins.connect(fig, plugins.LinkedBrush(points))

mpld3.display(fig)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el749219755588720884581358213"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el749219755588720884581358213", {"width": 640.0, "axes": [{"xlim": [4.0, 8.5], "markers": [], "bbox": [0.05, 0.7406976744186047, 0.20930232558139533, 0.20930232558139528], "yscale": "linear", "zoomable": true, "xscale": "linear", "sharey": ["el74921975539414184", "el74921975559231976", "el74921975559483744"], "ylim": [-0.5, 3.0], "id": "el74921975558908056", "lines": [], "axesbg": "#FFFFFF", "axesbgalpha": null, "texts": [], "images": [], "xdomain": [4.0, 8.5], "ydomain": [-0.5, 3.0], "paths": [], "axes": [{"fontsize": 10.0, "tickformat": "", "nticks": 10, "tickvalues": null, "position": "bottom", "grid": {"gridOn": false}, "scale": "linear"}, {"fontsize": 10.0, "tickformat": "", "nticks": 8, "tickvalues": null, "position": "left", "grid": {"gridOn": false}, "scale": "linear"}], "sharex": ["el74921975559757552", "el74921975560902472", "el74921975561998232"], "collections": [{"offsets": "data01", "id": "el74921975563497824", "offsetcoordinates": "data", "alphas": [0.6], "edgecolors": ["#000000"], "zorder": 1, "pathtransforms": [[7.027283689263066, 0.0, 0.0, 7.027283689263066, 0.0, 0.0]], "paths": [[[[0.0, -0.5], [0.13260155, -0.5], [0.25978993539242673, -0.44731684579412084], [0.3535533905932738, -0.3535533905932738], [0.44731684579412084, -0.25978993539242673], [0.5, -0.13260155], [0.5, 0.0], [0.5, 0.13260155], [0.44731684579412084, 0.25978993539242673], [0.3535533905932738, 0.3535533905932738], [0.25978993539242673, 0.44731684579412084], [0.13260155, 0.5], [0.0, 0.5], [-0.13260155, 0.5], [-0.25978993539242673, 0.44731684579412084], [-0.3535533905932738, 0.3535533905932738], [-0.44731684579412084, 0.25978993539242673], [-0.5, 0.13260155], [-0.5, 0.0], [-0.5, -0.13260155], [-0.44731684579412084, -0.25978993539242673], [-0.3535533905932738, -0.3535533905932738], [-0.25978993539242673, -0.44731684579412084], [-0.13260155, -0.5], [0.0, -0.5]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]]], "pathcoordinates": "display", "facecolors": ["#00007F", "#00007F", "#00007F", "#00007F", "#00007F", "#00007F", "#00007F", "#00007F", "#00007F", "#00007F", "#00007F", "#00007F", "#00007F", "#00007F", "#00007F", "#00007F", "#00007F", "#00007F", "#00007F", "#00007F", "#00007F", "#00007F", "#00007F", "#00007F", "#00007F", "#00007F", "#00007F", "#00007F", "#00007F", "#00007F", "#00007F", "#00007F", "#00007F", "#00007F", "#00007F", "#00007F", "#00007F", "#00007F", "#00007F", "#00007F", "#00007F", "#00007F", "#00007F", "#00007F", "#00007F", "#00007F", "#00007F", "#00007F", "#00007F", "#00007F", "#7CFF79", "#7CFF79", "#7CFF79", "#7CFF79", "#7CFF79", "#7CFF79", "#7CFF79", "#7CFF79", "#7CFF79", "#7CFF79", "#7CFF79", "#7CFF79", "#7CFF79", "#7CFF79", "#7CFF79", "#7CFF79", "#7CFF79", "#7CFF79", "#7CFF79", "#7CFF79", "#7CFF79", "#7CFF79", "#7CFF79", "#7CFF79", "#7CFF79", "#7CFF79", "#7CFF79", "#7CFF79", "#7CFF79", "#7CFF79", "#7CFF79", "#7CFF79", "#7CFF79", "#7CFF79", "#7CFF79", "#7CFF79", "#7CFF79", "#7CFF79", "#7CFF79", "#7CFF79", "#7CFF79", "#7CFF79", "#7CFF79", "#7CFF79", "#7CFF79", "#7CFF79", "#7CFF79", "#7CFF79", "#7CFF79", "#7CFF79", "#7F0000", "#7F0000", "#7F0000", "#7F0000", "#7F0000", "#7F0000", "#7F0000", "#7F0000", "#7F0000", "#7F0000", "#7F0000", "#7F0000", "#7F0000", "#7F0000", "#7F0000", "#7F0000", "#7F0000", "#7F0000", "#7F0000", "#7F0000", "#7F0000", "#7F0000", "#7F0000", "#7F0000", "#7F0000", "#7F0000", "#7F0000", "#7F0000", "#7F0000", "#7F0000", "#7F0000", "#7F0000", "#7F0000", "#7F0000", "#7F0000", "#7F0000", "#7F0000", "#7F0000", "#7F0000", "#7F0000", "#7F0000", "#7F0000", "#7F0000", "#7F0000", "#7F0000", "#7F0000", "#7F0000", "#7F0000", "#7F0000", "#7F0000"], "xindex": 0, "edgewidths": [1.0], "yindex": 1}]}, {"xlim": [1.5, 5.0], "markers": [], "bbox": [0.28023255813953485, 0.7406976744186047, 0.20930232558139533, 0.20930232558139528], "yscale": "linear", "zoomable": true, "xscale": "linear", "sharey": ["el74921975558908056", "el74921975559231976", "el74921975559483744"], "ylim": [-0.5, 3.0], "id": "el ...

# %% [markdown]
# ## Javascript plugin

# %%
import jinja2
import json
import numpy as np
import matplotlib.pyplot as plt

import mpld3
from mpld3 import plugins, utils


class HighlightLines(plugins.PluginBase):
    """A plugin to highlight lines on hover"""

    JAVASCRIPT = """
    mpld3.register_plugin("linehighlight", LineHighlightPlugin);
    LineHighlightPlugin.prototype = Object.create(mpld3.Plugin.prototype);
    LineHighlightPlugin.prototype.constructor = LineHighlightPlugin;
    LineHighlightPlugin.prototype.requiredProps = ["line_ids"];
    LineHighlightPlugin.prototype.defaultProps = {alpha_bg:0.3, alpha_fg:1.0}
    function LineHighlightPlugin(fig, props){
        mpld3.Plugin.call(this, fig, props);
    };

    LineHighlightPlugin.prototype.draw = function(){
      for(var i=0; i<this.props.line_ids.length; i++){
         var obj = mpld3.get_element(this.props.line_ids[i], this.fig),
             alpha_fg = this.props.alpha_fg;
             alpha_bg = this.props.alpha_bg;
         obj.elements()
             .on("mouseover", function(d, i){
                            d3.select(this).transition().duration(50)
                              .style("stroke-opacity", alpha_fg); })
             .on("mouseout", function(d, i){
                            d3.select(this).transition().duration(200)
                              .style("stroke-opacity", alpha_bg); });
      }
    };
    """

    def __init__(self, lines):
        self.lines = lines
        self.dict_ = {"type": "linehighlight",
                      "line_ids": [utils.get_id(line) for line in lines],
                      "alpha_bg": lines[0].get_alpha(),
                      "alpha_fg": 1.0}


N_paths = 50
N_steps = 100

x = np.linspace(0, 10, 100)
y = 0.1 * (np.random.random((N_paths, N_steps)) - 0.5)
y = y.cumsum(1)

fig, ax = plt.subplots(subplot_kw={'xticks': [], 'yticks': []})
lines = ax.plot(x, y.T, color='blue', lw=4, alpha=0.1)
plugins.connect(fig, HighlightLines(lines))

mpld3.display(fig)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el749219755398437046250019313"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#     mpld3.register_plugin("linehighlight", LineHighlightPlugin);
#     LineHighlightPlugin.prototype = Object.create(mpld3.Plugin.prototype);
#     LineHighlightPlugin.prototype.constructor = LineHighlightPlugin;
#     LineHighlightPlugin.prototype.requiredProps = ["line_ids"];
#     LineHighlightPlugin.prototype.defaultProps = {alpha_bg:0.3, alpha_fg:1.0}
#     function LineHighlightPlugin(fig, props){
#         mpld3.Plugin.call(this, fig, props);
#     };
#
#     LineHighlightPlugin.prototype.draw = function(){
#       for(var i=0; i<this.props.line_ids.length; i++){
#          var obj = mpld3.get_element(this.props.line_ids[i], this.fig),
#              alpha_fg = this.props.alpha_fg;
#              alpha_bg = this.props.alpha_bg;
#          obj.elements()
#              .on("mouseover", function(d, i){
#                             d3.select(this).transition().duration(50)
#                               .style("stroke-opacity", alpha_fg); })
#              .on("mouseout", function(d, i){
#                             d3.select(this).transition().duration(200)
#                               .style("stroke-opacity", alpha_bg); });
#       }
#     };
#
#        mpld3.draw_figure("fig_el749219755398437046250019313", {"width": 480.0, "axes": [{"xlim": [0.0, 10.0], "markers": [], "bbox": [0.125, 0.125, 0.775, 0.775], "yscale": "linear", "zoomable": true, "xscale": "linear", "sharey": [], "ylim": [-0.8425668698720463, 0.6947458934765465], "id": "el74921975566929088", "lines": [{"dasharray": "10,0", "coordinates": "data", "linewidth": 4.0, "alpha": 0.1, "color": "#0000FF", "zorder": 2, "xindex": 0, "id": "el74921975563778032", "yindex": 1, "data": "data01"}, {"dasharray": "10,0", "coordinates": "data", "linewidth": 4.0, "alpha": 0.1, "color": "#0000FF", "zorder": 2, "xindex": 0, "id": "el74921975567393960", "yindex": 2, "data": "data01"}, {"dasharray": "10,0", "coordinates": "data", "linewidth": 4.0, "alpha": 0.1, "color": "#0000FF", "zorder": 2, "xindex": 0, "id": "el74921975567394632", "yindex": 3, "data": "data01"}, {"dasharray": "10,0", "coordinates": "data", "linewidth": 4.0, "alpha": 0.1, "color": "#0000FF", "zorder": 2, "xindex": 0, "id": "el74921975567395136", "yindex": 4, "data": "data01"}, {"dasharray": "10,0", "coordinates": "data", "linewidth": 4.0, "alpha": 0.1, "color": "#0000FF", "zorder": 2, "xindex": 0, "id": "el74921975567395640", "yindex": 5, "data": "data01"}, {"dasharray": "10,0", "coordinates": "data", "linewidth": 4.0, "alpha": 0.1, "color": "#0000FF", "zorder": 2, "xindex": 0, "id": "el74921975567396144", "yindex": 6, "data": "data01"}, {"dasharray": "10,0", "coordinates": "data", "linewidth": 4.0, "alpha": 0.1, "color": "#0000FF", "zorder": 2, "xindex": 0, "id": "el74921975567396648", "yindex": 7, "data": "data01"}, {"dasharray": "10,0", "coordinates": "data", "linewidth": 4.0, "alpha": 0.1, "color": "#0000FF", "zorder": 2, "xindex": 0, "id": "el74921975567409504", "yindex": 8, "data": "data01"}, {"dasharray": "10,0", "coordinates": "data", "linewidth": 4.0, "alpha": 0.1, "color": "#0000FF", "zorder": 2, "xindex": 0, "id": "el74921975567410008", "yindex": 9, "data": "data01"}, {"dasharray": "10,0", "coordinates": "data", "linewidth": 4.0, "alpha": 0.1, "color": "#0000FF", "zorder": 2, "xindex": 0, "id": "el74921975567410512", "yindex": 10, "data": "data01"}, {"dasharray": "10,0", "coordinates": "data", "linewidth": 4.0, "alpha": 0.1, "color": "#0000FF", "zorder": 2, "xindex": 0, "id": "el74921975567411016", "yindex": 11, "data": "data01"}, {"dasharray": "10,0", "coordinates": "data", "linewidth": 4.0, "alpha": 0.1, "color": "#0000FF", "zorder": 2, "xindex": 0, "id": "el74921975567411520", "yindex": 12, "data": "data01"}, {"dasharray": "10,0", "coordinates": "data", "linewidth": 4.0, "alpha": 0.1, "color": "#0000FF", "zorder": 2, "xindex": 0, "id": "el74921975567412024", "yindex": 13, "data": "data01"}, {"dasharray": "10,0", "coordinates": "data", "linewidth": 4.0, "alpha": 0.1, "color": "#0000FF", "zorder": 2, "xindex": 0, "id": "el74921975567412528", "yindex": 14, "data": "data01"}, {"dasharray": "10,0", "coordinates": "data", "linewidth": 4.0, "alpha": 0.1, "color": "#0000FF", "zorder": 2, "xindex": 0, "id": "el74921975567413032", "yindex": 15, "data": "data01"}, {"dasharray": "10,0", "coordinates": "data", "linewidth": 4.0, "alpha": 0.1, "color": "#0000FF", "zorder": 2, "xindex": 0, "id": "el74921975567421792", "yindex": 16, "data": "data01"}, {"dasharray": "10,0", "coordinates": "data", "linewidth": 4.0, "alpha": 0.1, "color": "#0000FF", "zorder": 2, "xindex": 0, "id": "el74921975567422296", "yindex": 17, "data": "data01"}, {"dasharray": "10,0", "coordinates": "data", "linewidth": 4.0, "alpha": 0.1, "color": "#0000FF", "zorder": 2, "xindex": 0, "id": "el74921975567422800", "yindex": 18, "data": "data01"}, {"dasharray": "10,0", "coordinates": "data", "linewidth": 4.0, "alpha": 0.1, "color": "#0000FF", "zorder": 2, "xindex": 0, "id": "el74921975567423304", "yindex": 19, "data": "data01"}, {"dasharray": "10,0", "coordinates": "data", "linewidth": 4.0, "alpha": 0.1, "color": "#0000FF", "zorder": 2, "xindex": 0, "id": "el74921975567423808", "yindex": 20, "da ...
